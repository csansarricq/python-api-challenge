# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0       zahedan  29.4963   60.8629      2.95       100           2
# 1        1     jiaojiang  28.6803  121.4428     13.38        36         100
# 2        2  puerto ayora  -0.7393  -90.3518     24.75        94          36
# 3        3         wewak  -3.5534  143.6268     29.01        74          17
# 4        4        thurso  58.5927   -3.5259      0.14        83          33
#
#    Wind Speed Country        Date
# 0        4.12      IR  1737340070
# 1        0.24      CN  1737340071
# 2        3.13      EC  1737340072
# 3        2.05      PG  1737339984
# 4        3.01      GB  1737340074

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

#no display?

# Configure the map plot
city_map = city_data_df.hvplot.points("Lng", 
                                      "Lat", 
                                      geo = True,
                                      size = "Humidity",
                                      color = "City",
                                      tiles = "OSM",
                                      frame_width = 800,
                                      frame_height = 600
                                     )


# Display the map
city_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# my criterias:
# max temp cannot be lower than 0 C or higher than 30 C
# wind speed has to be less than 10 m/s
# cloudiness sould be less than 5
# humidity less than 65

ideal_weather_df= city_data_df.loc[(city_data_df["Max Temp"] >= 0) & (city_data_df["Max Temp"] <= 30)
                    &(city_data_df["Wind Speed"] < 10) & (city_data_df["Cloudiness"] <5) 
                    & (city_data_df["Humidity"] < 65)]

# Drop any rows with null values
ideal_weather_df.dropna()

# Display sample data
ideal_weather_df.head()
ideal_weather_df.count()
# Out:
# City_ID       47
# City          47
# Lat           47
# Lng           47
# Max Temp      47
# Humidity      47
# Cloudiness    47
# Wind Speed    47
# Country       47
# Date          47
# dtype: int64

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                                                   City Country      Lat  \
# 33                                               ha'il      SA  27.5219
# 73   chak two hundred forty-nine thal development a...      PK  31.1796
# 84                                              mahriz      IR  31.5917
# 94                                             paulden      US  34.8856
# 103                                       umm kaddadah      SD  13.6017
# 110                                       san patricio      US  28.0170
# 140                                             magway      MM  20.1500
# 143                                              pusad      IN  19.9000
# 158                                            nguigmi      NE  14.2495
# 161                                          balnearia      AR -31.0088
# 195                                  fray luis beltran      AR -39.3167
# 198                                            hanting      CN  36.7708
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
#url = "https://api.geoapify.com/v2/places" + geoapify_key 
#hotel_url = url
#hotel_loc = requests.get(hotel_url).json()
#print(json.dumps(hotel_loc, indent = 4, sort_keys = True))
# Out:
# {
#     "error": "Unauthorized",
#     "message": "Invalid apiKey",
#     "statusCode": 401
# }

# %%
# Set parameters to search for a hotel
radius = 10000
params = { "categories": "accommodation.hotel",
        "apiKey": geoapify_key
          
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    latitude = row["Lat"]
    longitude = row["Lng"]

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] =  f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"


    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# ha'il - nearest hotel: فندق كلاسيك
# chak two hundred forty-nine thal development authority - nearest hotel: No hotel found
# mahriz - nearest hotel: هتل رستوران شاه عباسی
# paulden - nearest hotel: No hotel found
# umm kaddadah - nearest hotel: No hotel found
# san patricio - nearest hotel: No hotel found
# magway - nearest hotel: Rolex Guesthouse
# pusad - nearest hotel: No hotel found
# nguigmi - nearest hotel: Guest PAM
# balnearia - nearest hotel: No hotel found
# fray luis beltran - nearest hotel: Casa Puente Molina
# hanting - nearest hotel: 山东高速服务区管理有限公司青银路潍坊分公司高速宾馆
# tindouf - nearest hotel: محمد بوسبي
# de aar - nearest hotel: No hotel found
# shibganj - nearest hotel: No hotel found
# lanzhou - nearest hotel: 西园宾馆
# dourbali - nearest hotel: No hotel found
# timimoun - nearest hotel: أناف
# salalah - nearest hotel: Muscat International Hotel
# dhromolaxia - nearest hotel: Helen of Troy gardens
# tamanrasset - nearest hotel: فندق الأمان
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points("Lng", 
                                      "Lat", 
                                      geo = True,
                                      size = "Humidity",
                                      color = "City",
                                      tiles = "OSM",
                                      hover_cols = ["Hotel Name", "Country"],
                                      frame_width = 800,
                                      frame_height = 600
                                     )

# Display the map
hotel_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)

# %%
# why does the map not show up?
